# %% [markdown]
# <a href="https://colab.research.google.com/github/SahilGaneshKarpate/session-20-assignment/blob/main/optional%20task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import joblib

df = pd.read_csv("car_advertisement dataset.csv", encoding="latin1")

print("Dataset Loaded Successfully")
print(df.head())
# Out:
# Dataset Loaded Successfully
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
print("\nShape of Dataset:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape of Dataset:
# (9576, 10)
#
# Column Names:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')
#
# Data Types:
# car              object
# price           float64
# body             object
# mileage           int64
# engV            float64
# engType          object
# registration     object
# year              int64
# model            object
# drive            object
# dtype: object
#
# Missing Values:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
le = LabelEncoder()

for col in df.select_dtypes(include="object").columns:
    df[col] = le.fit_transform(df[col].astype(str))

print("\nCategorical Columns Converted Successfully")
print(df.head())
# Out:
# Categorical Columns Converted Successfully
#    car    price  body  mileage  engV  engType  registration  year  model  \
# 0   26  15500.0     0       68   2.5        1             1  2010    496
# 1   53  20500.0     3      173   1.8        1             1  2011    336
# 2   53  35000.0     2      135   5.5        3             1  2008    244
# 3   53  17800.0     5      162   1.8        0             1  2012    210
# 4   53  33000.0     4       91   NaN        2             1  2013    336
#
#    drive
# 0      1
# 1      3
# 2      3
# 3      0
# 4      2

# %%
X = df.drop("price", axis=1)
y = df["price"]

print("\nFeatures Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (9576, 9)
# Target Shape: (9576,)

# %%
imputer = SimpleImputer(strategy="mean")
X = imputer.fit_transform(X)

print("\nMissing Values Filled")
# Out:
# Missing Values Filled

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

print("\nFeatures Scaled Successfully")
print(X[:5])
# Out:
# Features Scaled Successfully
# [[-0.91594365 -1.43167531 -0.71850594 -0.02526882 -0.48694266  0.24945865
#    0.48022347  0.16271153  0.18891083]
#  [ 0.13809396  0.43791732  0.34613711 -0.14613564 -0.48694266  0.24945865
#    0.62171511 -0.46817241  2.0703566 ]
#  [ 0.13809396 -0.18528022 -0.03916228  0.49273182  1.01554257  0.24945865
#    0.19724018 -0.83093067  2.0703566 ]
#  [ 0.13809396  1.68431241  0.23460308 -0.14613564 -1.23818528  0.24945865
#    0.76320676 -0.96499351 -0.75181205]
#  [ 0.13809396  1.06111487 -0.48529842  0.          0.26429996  0.24945865
#    0.9046984  -0.46817241  1.12963371]]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42
)

print("\nTraining Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)
# Out:
# Training Data Shape: (6415, 9)
# Testing Data Shape: (3161, 9)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

print("\nModel Training Completed")
# Out:
# Model Training Completed

# %%
y_pred = model.predict(X_test)

print("\nFirst 10 Predictions")
print(y_pred[:10])
# Out:
# First 10 Predictions
# [ 7607.53837872 10241.99728191 33012.16535984 21396.35908135
#  23438.22793642 29652.3042247  28045.24054078 16314.11144684
#  27623.1926451   3574.49295784]

# %%
r2 = r2_score(y_test, y_pred)

print("\nR2 Score:", r2)
# Out:
# R2 Score: 0.22613669831400363

# %%
joblib.dump(model, "car_model.pkl")
joblib.dump(scaler, "car_scaler.pkl")

print("\nModel Saved Successfully")
# Out:
# Model Saved Successfully
